# %% [markdown]
# <a href="https://colab.research.google.com/github/CharlyUP-300/Inteligencia-Artificial-Segundo-Corte/blob/main/Taller4final/Taller_Practico_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# <br><br>
#
# <img src="https://lh3.googleusercontent.com/d/1AFzLBrKfNJ4kZHsG-ojLqNNY1chXYv1m" width="400" alt="Logo Unipacifico">
#
# <br><br><br>
#
# <p style="font-size: 24px; font-weight: bold; margin: 5px 0;">UNIVERSIDAD DEL PACÍFICO</p>
# <p style="font-size: 18px; font-weight: bold; margin: 5px 0;">INGENIERÍA DE SISTEMAS</p>
# <p style="font-size: 16px; margin: 5px 0; color: #555;">Inteligencia Artificial</p>
#
# <br><br><br>
#
# <p style="font-size: 24px; font-weight: bold; margin: 5px 0;">Taller Práctico No. 4</p>
# <p style="font-size: 20px; font-weight: bold; margin: 5px 0;">Librerías NumPy, Matplotlib y Seaborn</p>
# <p style="font-size: 16px; margin: 5px 0; color: #333;">Caso 5: Mantenimiento Predictivo en una Fábrica Inteligente</p>
#
# <br><br><br><br>
#
# <p style="font-size: 15px; margin: 5px 0;"><strong>Docente:</strong> Wilman Andrés Quiñónez V.</p>
#
# <p style="font-size: 15px; margin: 5px 0;">
#   <strong>Estudiantes:</strong><br>
#   Jhon Jader Riascos Angulo<br>
#   Charly Jhoan Murillo Hernández<br>
#   Gabriel Alejandro Sanchez Alarcon<br>
#   Brayan David Riascos Murillo
# </p>
#
# <p style="font-size: 15px; margin: 5px 0;"><strong>Semestre:</strong> Octavo</p>
# <p style="font-size: 15px; margin: 5px 0;"><strong>Fecha:</strong> 22 de Junio de 2026</p>
#
# </center>

# %% [markdown]
# # **1. Introducción**
#
# En la actualidad, la Inteligencia Artificial y la Ciencia de Datos se han convertido en áreas fundamentales para la solución de problemas en diferentes sectores, permitiendo transformar grandes volúmenes de información en conocimiento útil para la toma de decisiones. Sin embargo, antes de implementar modelos predictivos o sistemas inteligentes, es necesario realizar procesos de preparación, análisis y visualización de los datos, con el fin de comprender su comportamiento e identificar patrones relevantes.
#
# Dentro del ecosistema científico de Python, las librerías NumPy, Matplotlib y Seaborn representan herramientas esenciales para el desarrollo de estas tareas. NumPy proporciona estructuras de datos multidimensionales y operaciones matemáticas eficientes; Matplotlib permite la construcción de representaciones gráficas que facilitan la interpretación de la información; y Seaborn complementa este proceso mediante visualizaciones estadísticas avanzadas que favorecen el análisis exploratorio de datos.
#
# En el presente taller se desarrollan actividades orientadas a la manipulación, procesamiento y visualización de datos, aplicando técnicas básicas utilizadas en proyectos de Inteligencia Artificial. Asimismo, se busca fortalecer las capacidades analíticas y el pensamiento crítico mediante la interpretación de resultados y la formulación de conclusiones fundamentadas, contribuyendo al desarrollo de competencias propias de la Ingeniería de Sistemas y la Ciencia de Datos.

# %% [markdown]
# # **2. Objetivos**
#
# ##**2.1. General**
# Aplicar las librerías NumPy, Matplotlib y Seaborn para el procesamiento, análisis estadístico y visualización de datos, con el propósito de interpretar información, identificar patrones relevantes y apoyar la toma de decisiones en contextos relacionados con la Inteligencia Artificial y la Ciencia de Datos.
#
# ##**2.2 Especificos:**
# - Utilizar la librería NumPy para manipular estructuras de datos multidimensionales y realizar operaciones matemáticas y estadísticas fundamentales.
#
# - Emplear Matplotlib para construir representaciones gráficas que permitan analizar tendencias y comportamientos presentes en los datos.
#
# - Aplicar Seaborn para desarrollar visualizaciones estadísticas que faciliten el estudio de distribuciones y relaciones entre variables.
#
# - Interpretar los resultados obtenidos a partir del análisis y la visualización de datos para formular conclusiones fundamentadas.
#
# - Comprender la importancia de estas herramientas dentro del proceso de análisis exploratorio de datos y su aplicación en proyectos de Inteligencia Artificial.

# %% [markdown]
# # 3. **Investigación Conceptual**
#
# ---
#
# ## **3.1 NumPy**
#
# ### ¿Qué es NumPy?
#
# **NumPy** (*Numerical Python*) es una librería fundamental de Python especializada en la computación científica y el procesamiento eficiente de datos numéricos. Su principal función es proporcionar estructuras de datos multidimensionales y herramientas optimizadas para realizar operaciones matemáticas complejas de manera rápida y eficiente.
#
# ### ¿Por qué NumPy es más eficiente que las listas tradicionales de Python?
#
# NumPy es más eficiente que las listas tradicionales de Python debido a que almacena los datos en bloques continuos de memoria y utiliza código optimizado escrito en lenguaje C. Esto permite ejecutar operaciones matemáticas de forma mucho más rápida, reducir el consumo de recursos y evitar el uso excesivo de bucles `for`.
#
# Sus principales ventajas son:
#
# * **Almacenamiento contiguo:** permite acceder a los datos de forma más rápida y eficiente.
# * **Vectorización:** realiza operaciones sobre grandes conjuntos de datos simultáneamente.
# * **Optimización:** utiliza código interno altamente eficiente para mejorar el rendimiento.
#
# ### ¿Qué es un ndarray?
#
# El **ndarray** (*N-dimensional Array*) es la estructura de datos principal de NumPy. Se trata de un arreglo multidimensional homogéneo, es decir, todos sus elementos deben ser del mismo tipo de dato. Esta estructura permite almacenar y manipular grandes volúmenes de información de forma eficiente.
#
# ### ¿Qué relación existe entre NumPy y el álgebra lineal?
#
# NumPy incorpora herramientas de álgebra lineal que permiten realizar operaciones matemáticas fundamentales como la manipulación de vectores y matrices, el cálculo de determinantes, matrices inversas, transpuestas y multiplicaciones matriciales. Estas operaciones constituyen la base matemática utilizada en Inteligencia Artificial y Machine Learning.
#
# ### ¿Cómo utilizan los modelos de Deep Learning las matrices de NumPy?
#
# Los modelos de Deep Learning utilizan matrices para representar los datos de entrada, los pesos y los sesgos de las redes neuronales. Durante el entrenamiento, se realizan millones de operaciones matemáticas entre estas matrices para que el modelo aprenda patrones y pueda realizar predicciones de manera automática.
#
# ---
#
# ## **3.2 Matplotlib**
#
# ### ¿Qué es Matplotlib?
#
# **Matplotlib** es una librería de Python especializada en la visualización de datos. Permite construir gráficos científicos, estadísticos e interactivos que facilitan la interpretación y comunicación de la información.
#
# ### ¿Qué tipos de gráficos permite construir?
#
# Matplotlib permite crear una gran variedad de gráficos, entre los que destacan:
#
# * Gráficos de líneas.
# * Gráficos de barras.
# * Histogramas.
# * Gráficos de dispersión.
# * Gráficos circulares.
# * Diagramas de áreas.
# * Diagramas de caja y bigotes (*boxplots*).
#
# ### ¿Por qué la visualización de datos es importante en IA?
#
# La visualización de datos es importante porque permite identificar patrones, tendencias, anomalías y relaciones entre variables antes de construir modelos de Inteligencia Artificial. Un buen análisis visual facilita la comprensión de los datos y mejora la toma de decisiones.
#
# ### ¿Cómo ayuda Matplotlib en el análisis exploratorio de datos (EDA)?
#
# Matplotlib ayuda a comprender el comportamiento de los datos mediante representaciones gráficas que permiten detectar distribuciones, valores atípicos y posibles correlaciones entre variables, facilitando el análisis previo al entrenamiento de modelos predictivos.
#
# ---
#
# ## **3.3 Seaborn**
#
# ### ¿Qué es Seaborn?
#
# **Seaborn** es una librería de visualización estadística construida sobre Matplotlib. Está diseñada para crear gráficos más atractivos, modernos y fáciles de interpretar, especialmente en procesos de análisis exploratorio de datos.
#
# ### ¿Qué ventajas ofrece frente a Matplotlib?
#
# Seaborn ofrece varias ventajas:
#
# * Presenta una apariencia visual más profesional.
# * Requiere menos líneas de código.
# * Facilita la creación de gráficos estadísticos avanzados.
# * Se integra fácilmente con estructuras de datos de Pandas.
#
# ### ¿Qué son los mapas de calor (Heatmaps)?
#
# Los mapas de calor son representaciones gráficas que utilizan una escala de colores para mostrar la intensidad de la relación existente entre diferentes variables. Son ampliamente utilizados para visualizar correlaciones en conjuntos de datos.
#
# ### ¿Por qué las matrices de correlación son importantes en Machine Learning?
#
# Las matrices de correlación permiten identificar la fuerza y la dirección de la relación entre variables. Esta información ayuda a seleccionar las características más relevantes, eliminar variables redundantes y mejorar el rendimiento de los modelos de Machine Learning.

# %% [markdown]
# # **4. Ejercicios Guía**
# ## **4.1 Manipulación de matrices con NumPy**
#
# - Mostrar el elemento central.
# - Mostrar la segunda fila.
# - Mostrar la tercera columna.

# %%
import numpy as np

matriz = np.array([
    [10,20,30],
    [40,50,60],
    [70,80,90]
])

# Mostrar el elemento central
print("Elemento central:", matriz[1,1])

# Mostrar la segunda fila
print("Segunda fila:", matriz[1])

# Mostrar la tercera columna
print("Tercera columna:", matriz[:,2])
# Out:
# Elemento central: 50
# Segunda fila: [40 50 60]
# Tercera columna: [30 60 90]

# %% [markdown]
# ## **4.2 Operaciones matemáticas**

# %%
import numpy as np

datos = np.array([12,18,20,25,30,35,40])

print("Promedio:", np.mean(datos))
print("Máximo:", np.max(datos))
print("Mínimo:", np.min(datos))
print("Desviación:", np.std(datos))
# Out:
# Promedio: 25.714285714285715
# Máximo: 40
# Mínimo: 12
# Desviación: 9.176278201572414

# %% [markdown]
# **Interpretación**
#
# Como la desviación estándar no es muy pequeña ni excesivamente grande, los datos presentan una dispersión moderada alrededor de la media, sin mostrar valores extremadamente alejados del resto.
#
# ###4.2.1. ¿Qué representa la desviación estándar?
#
# La desviación estándar representa qué tan alejados están los datos del promedio. En este caso, la desviación estándar es de aproximadamente 9.04, lo que indica que los valores suelen diferir del promedio (25.71) en alrededor de 9 unidades.
#
# ###4.2.2. ¿Por qué es importante conocer la dispersión de los datos?
#
# Porque permite saber si los datos están concentrados cerca del promedio o si están muy dispersos. En este conjunto de datos, una desviación estándar de 9.04 muestra que existe una variabilidad moderada entre los valores, ya que estos se distribuyen entre 12 y 40. Esta información es útil para comprender mejor el comportamiento de los datos y realizar análisis más precisos.

# %% [markdown]
# ## **4.3 Generación de datos aleatorios**
#
# Complete el código, ejecútelo y grafique la distribución norma

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generar 1000 datos con distribución normal
datos = np.random.normal(
    loc=50,
    scale=10,
    size=1000
)

# Graficar la distribución
sns.histplot(datos, kde=True)

plt.title("Distribución Normal")
plt.xlabel("Valores")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# **Interpretación**
#
# Al observar la gráfica, se observa que la mayor parte de los datos se encuentra alrededor del valor 50, que corresponde a la media de la distribución. A medida que los valores se alejan de este punto, la cantidad de datos disminuye, por lo que los valores muy bajos o muy altos aparecen con menor frecuencia. Esto genera la característica forma de campana de una distribución normal.
#
# ###4.3.1. ¿Qué significa distribución normal?
#
# La distribución normal es una forma de representar cómo se distribuyen los datos alrededor de un valor central. Se caracteriza por tener una forma de campana simétrica, donde la mayoría de los valores se concentra cerca de la media y los valores más alejados aparecen con menor frecuencia. Este tipo de distribución es muy común en fenómenos naturales, sociales y científicos.
#
# ###4.3.2. ¿Por qué muchos algoritmos asumen distribuciones aproximadamente normales?
#
# Muchos algoritmos asumen distribuciones aproximadamente normales porque este tipo de datos facilita el análisis estadístico y mejora el rendimiento de los modelos. Al estar la información concentrada alrededor de un valor central y existir menos valores extremos, es más sencillo identificar patrones, realizar predicciones y obtener resultados más estables y precisos.

# %% [markdown]
# #**5. Visualización de Datos**
#
# ##**5.1. Matplotlib**

# %%
import matplotlib.pyplot as plt

epocas = [1,2,3,4,5,6,7,8]
accuracy = [60,68,75,81,85,88,90,92] # Investigar este concepto
plt.plot(epocas,accuracy)
plt.title("Accuracy por época")
plt.xlabel("Épocas")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# **Interpretación de la gráfica**
#
# La gráfica muestra que el accuracy aumenta progresivamente desde 60% hasta 92% a medida que avanzan las épocas. Esto indica que el modelo está aprendiendo correctamente de los datos de entrenamiento y mejora su capacidad para realizar predicciones precisas con cada iteración.
#
# ### **5.1.1. Accuracy**
#
# Accuracy (precisión) es una métrica que indica qué porcentaje de predicciones realizó correctamente un modelo de Inteligencia Artificial o Machine Learning. Mientras más alto sea su valor, mejor es el desempeño del modelo.
#
# ###5.1.2. ¿Qué representa una época (Epoch)
#
# Una época es una pasada completa del modelo por todos los datos de entrenamiento. En cada época, el modelo aprende un poco más y ajusta sus parámetros para mejorar sus resultados.
#
# ###5.1.3. Grafico Histrograma

# %%
#Gráfico Histograma
datos = np.random.normal(70,15,1000)
plt.hist(datos)
plt.show()

# %% [markdown]
# ####5.1.3.1. ¿Qué representa un histograma?
#
# Un histograma es un gráfico que muestra cómo se distribuyen los datos según su frecuencia. Cada barra representa un rango de valores y su altura indica cuántos datos se encuentran dentro de ese intervalo. En este caso, se observa que la mayor cantidad de datos se concentra entre aproximadamente 60 y 80, mientras que los valores muy bajos o muy altos aparecen con menor frecuencia.
#
# ####5.1.3.2. ¿Qué utilidad tiene para comprender un dataset?
#
# El histograma permite visualizar rápidamente la distribución de los datos, identificar dónde se concentra la mayoría de los valores y detectar posibles anomalías o valores atípicos. En este conjunto de datos, el histograma muestra una forma cercana a una distribución normal, lo que indica que la mayoría de los registros se agrupan alrededor de un valor central y que los extremos son poco frecuentes.
#
# ###5.1.4. Grafico de barras

# %%
#Gráfico de Barras, complete el código y observe la gráfica.
clases = ['Sano','Roya','Mosaico','Mancha']
cantidad = [1200,850,430,320]
plt.bar(clases,cantidad)
plt.title("Distribución de clases")
plt.show()

# %% [markdown]
# ####5.1.4.1 ¿Qué representa el gráfico de barras?
#
# El gráfico de barras representa la cantidad de muestras que existen en cada categoría o clase del conjunto de datos. Cada barra muestra la frecuencia de una clase específica, permitiendo comparar visualmente cuál tiene más o menos registros.
#
# ####5.1.4.2 ¿Qué se puede interpretar de esta gráfica?
#
# La clase "Sano" es la más frecuente con 1200 muestras, seguida de "Roya" con 850. Por otro lado, "Mosaico" y "Mancha" tienen una cantidad considerablemente menor de registros. Esto indica que el conjunto de datos no está completamente equilibrado, ya que algunas clases tienen muchas más observaciones que otras

# %% [markdown]
# ##**5.2. Seaborn**

# %%
import pandas as pd
import seaborn as sns
datos = pd.DataFrame({
 'Edad':[20,25,30,35,40],
 'Horas':[2,4,6,8,10],
 'Nota':[60,70,80,90,100]
})
correlacion = datos.corr()
sns.heatmap(
 correlacion,
 annot=True
)
plt.show()

# %% [markdown]
# ####¿Qué representa?
#
# Representa la relación entre las variables Edad, Horas y Nota. Los valores de la matriz de correlación van de -1 a 1, donde 1 indica una correlación positiva perfecta, -1 una correlación negativa perfecta y 0 indica que no existe relación lineal.
#
# ####Interpretación natural
#
# La gráfica muestra una correlación positiva perfecta entre Edad, Horas y Nota. Esto significa que cuando una de las variables aumenta, las demás también aumentan de forma proporcional. En este conjunto de datos, existe una relación directa muy fuerte entre las tres variables, por lo que todas presentan un coeficiente de correlación igual a 1.
#
# ###***5.2.1 Grafico Boxplot***

# %%
#Gráfico Boxplot
sns.boxplot(x=datos["Nota"])
plt.show()

# %% [markdown]
# ####5.2.1.1 ¿Qué son los valores atípicos (Outliers)?
#
# Los valores atípicos u outliers son datos que se alejan significativamente del comportamiento general del conjunto de datos. Son observaciones inusualmente altas o bajas en comparación con la mayoría de los valores y pueden deberse a errores de medición, registros incorrectos o situaciones poco frecuentes.
#
# ####5.2.1.2. ¿Por qué pueden afectar el entrenamiento de un modelo?
#
# Los outliers pueden afectar el entrenamiento de un modelo porque distorsionan los patrones reales presentes en los datos. Al ser valores extremos, pueden influir en medidas como la media y la desviación estándar, provocando que el modelo aprenda relaciones incorrectas o reduzca su precisión al realizar predicciones. Por esta razón, es importante identificarlos y analizarlos antes de entrenar un modelo de Machine Learning.

# %% [markdown]
# <br><br>
#
# <hr style="border: 2px solid #2c3e50;">
# <br>
#
# <div style="text-align: center;">
#   <h1 style="color: #2c3e50; font-size: 32px; margin: 0; text-align: center;"><b>PARTE II: DESARROLLO DEL CASO PRÁCTICO</b></h1>
#   <h2 style="color: #e74c3c; font-size: 24px; margin: 10px 0; text-align: center;"><b>CASO 5: Mantenimiento Predictivo en una Fábrica Inteligente</b></h2>
#   <p style="font-size: 16px; color: #555; text-align: center;"><i>Aplicación práctica de NumPy, Matplotlib y Seaborn</i></p>
# </div>
#
# <br>
# <hr style="border: 2px solid #2c3e50;">
#
# <br><br>

# %% [markdown]
# # 6. **Configuración del entorno de trabajo**
#
# En esta sección se importan las librerías necesarias para la generación, procesamiento, análisis y visualización de los datos sintéticos que serán utilizados en el caso de estudio.
#
# Además, se configura una semilla aleatoria para garantizar la reproducibilidad de los resultados, permitiendo que el análisis pueda ejecutarse nuevamente obteniendo los mismos datos.

# %%
# Importación de librerías

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configuración estética de las gráficas
sns.set_theme(style="whitegrid")

# Configuración para reproducibilidad
np.random.seed(42)

print("Librerías cargadas correctamente.")
# Out:
# Librerías cargadas correctamente.

# %% [markdown]
# # 7. Generación de datos sintéticos
#
# Para simular el comportamiento de una fábrica inteligente, se generarán 500 observaciones sintéticas que representarán el estado operativo de distintas máquinas industriales.
#
# Los datos no serán completamente aleatorios, sino que se establecerán relaciones lógicas entre las variables para que el análisis exploratorio produzca resultados coherentes y representativos de un entorno industrial real.
#
# Se asume que un incremento en la temperatura, la vibración, las horas de uso y el consumo eléctrico aumenta la probabilidad de que una máquina presente una falla.

# %%
# Número de observaciones
n = 500

# Generación de variables

temperatura = np.random.normal(80, 10, n)

vibracion = np.random.normal(4, 1.2, n)

horas_uso = np.random.randint(500, 700, n)

consumo_electrico = np.random.normal(50, 10, n)

# Regla para determinar la falla

puntaje_falla = (
    (temperatura > 90).astype(int)
    + (vibracion > 5).astype(int)
    + (horas_uso > 3000).astype(int)
    + (consumo_electrico > 60).astype(int)
)

falla = np.where(puntaje_falla >= 2, "Sí", "No")

# Construcción del DataFrame

datos = pd.DataFrame({
    "Temperatura del Motor": temperatura,
    "Vibración": vibracion,
    "Horas de Uso": horas_uso,
    "Consumo Eléctrico": consumo_electrico,
    "Falla": falla
})

# Mostrar las primeras filas

datos.head(15)
# Out:
#     Temperatura del Motor  Vibración  Horas de Uso  Consumo Eléctrico Falla
# 0               84.967142   5.111413           618          43.781817    No
# 1               78.617357   6.291300           671          57.013731    No
# 2               86.476885   2.321719           548          60.310629    No
# 3               95.230299   4.675563           603          51.085427    No
# 4               77.658466   3.219229           560          54.626263    No
# 5               77.658630   3.415450           694          71.178559    No
# 6               95.792128   3.289127           622          38.273967    No
# 7               87.674347   2.963211           633          37.665319    No
# 8               75.305256   4.058226           508          56.949979    No
# 9               85.425600   3.002860           505          69.465428    No
# 10              75.365823   4.324548           572          47.395014    No
# ...

# %% [markdown]
# ---
#
# # 8. Análisis Estadístico (NumPy)
#
# En esta fase, se utilizará **NumPy** para extraer estadísticas descriptivas fundamentales de las variables numéricas simuladas. Esto nos permitirá comprender la tendencia central, la dispersión y la distribución de los datos operativos de las máquinas antes de proceder a la visualización.
#
# Se calcularán métricas como la media, mediana, desviación estándar, varianza y percentiles.

# %%
# Lista de columnas numéricas para iterar
columnas_numericas = ["Temperatura del Motor", "Vibración", "Horas de Uso", "Consumo Eléctrico"]

print("="*50)
print(" ESTADÍSTICAS DESCRIPTIVAS DE LAS MÁQUINAS")
print("="*50)

for col in columnas_numericas:
    # Convertir la columna de Pandas a un array de NumPy
    data_array = datos[col].values

    # Cálculos estadísticos con NumPy
    media = np.mean(data_array)
    mediana = np.median(data_array)
    varianza = np.var(data_array)
    desviacion = np.std(data_array)
    p25, p50, p75 = np.percentile(data_array, [25, 50, 75])

    print(f"\n⚙️ Variable: {col.upper()}")
    print(f"   • Media:               {media:.2f}")
    print(f"   • Mediana:             {mediana:.2f}")
    print(f"   • Varianza:            {varianza:.2f}")
    print(f"   • Desviación Estándar: {desviacion:.2f}")
    print(f"   • Rango Intercuartil:  {p25:.2f} (P25) - {p75:.2f} (P75)")

print("\n" + "="*50)
print(" CONTEO DE FALLAS (Variable Objetivo)")
print("="*50)
print(datos['Falla'].value_counts())
# Out:
# ...
#  ESTADÍSTICAS DESCRIPTIVAS DE LAS MÁQUINAS
# ...
#
# ⚙️ Variable: TEMPERATURA DEL MOTOR
#    • Media:               80.07
#    • Mediana:             80.13
#    • Varianza:            96.09
#    • Desviación Estándar: 9.80
#    • Rango Intercuartil:  73.00 (P25) - 86.37 (P75)
#
# ⚙️ Variable: VIBRACIÓN
#    • Media:               4.04
#    • Mediana:             4.03
#    • Varianza:            1.37
#    • Desviación Estándar: 1.17
#    • Rango Intercuartil:  3.29 (P25) - 4.78 (P75)
#
# ⚙️ Variable: HORAS DE USO
#    • Media:               597.90
#    • Mediana:             599.00
#    • Varianza:            3296.37
#    • Desviación Estándar: 57.41
#    • Rango Intercuartil:  547.00 (P25) - 647.00 (P75)
#
# ⚙️ Variable: CONSUMO ELÉCTRICO
#    • Media:               49.89
#    • Mediana:             50.32
#    • Varianza:            91.44
#    • Desviación Estándar: 9.56
#    • Rango Intercuartil:  43.50 (P25) - 56.25 (P75)
#
# ...
#  CONTEO DE FALLAS (Variable Objetivo)
# ...
# Falla
# No    468
# ...

# %% [markdown]
# ---
#
# # 9. Análisis Visual (Matplotlib)
#
# A continuación, se empleará **Matplotlib** para generar representaciones gráficas básicas que faciliten la identificación visual de la distribución de los datos y posibles valores atípicos (*outliers*).
#
# Se graficarán histogramas para comprender el comportamiento individual de las variables de temperatura y consumo, y gráficos de dispersión para observar correlaciones iniciales.
#
# En esta sección se analiza de forma individual el comportamiento de las variables operativas clave utilizando histogramas y gráficos de dispersión independientes.

# %%
# 1. Histograma de Temperatura
plt.figure(figsize=(6, 4))
plt.hist(datos['Temperatura del Motor'], bins=20, color='coral', edgecolor='black')
plt.title("Distribución de Temperatura")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Frecuencia")
plt.show()

# 2. Histograma de Vibración
plt.figure(figsize=(6, 4))
plt.hist(datos['Vibración'], bins=20, color='mediumpurple', edgecolor='black')
plt.title("Distribución de Vibración")
plt.xlabel("Vibración (mm/s)")
plt.ylabel("Frecuencia")
plt.show()

# 3. Dispersión: Temperatura vs Vibración
plt.figure(figsize=(6, 4))
plt.scatter(datos['Temperatura del Motor'], datos['Vibración'], alpha=0.6, color='dodgerblue')
plt.title("Temperatura vs Vibración")
plt.xlabel("Temperatura (°C)")
plt.ylabel("Vibración (mm/s)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# 4. Dispersión: Horas de Uso vs Consumo Eléctrico
plt.figure(figsize=(6, 4))
plt.scatter(datos['Horas de Uso'], datos['Consumo Eléctrico'], alpha=0.6, color='seagreen')
plt.title("Horas de Uso vs Consumo")
plt.xlabel("Horas de Uso")
plt.ylabel("Consumo (kWh)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### **Interpretación de los Gráficos de Matplotlib**
#
# * **Distribución de Temperatura:** La mayoría de las temperaturas de los motores se concentran cerca de los 80°C. Las temperaturas superiores a los 90°C representan un riesgo severo de falla por sobrecalentamiento.
# * **Distribución de Vibración:** Se observa una concentración típica alrededor de los 4 mm/s. Valores superiores a los 5.5 mm/s sugieren la presencia de desajustes mecánicos en el equipo.
# * **Temperatura vs Vibración:** Se evidencia que las máquinas con mayores temperaturas de operación tienden a presentar mayores niveles de vibración, aumentando la probabilidad de falla del motor.
# * **Horas de Uso vs Consumo:** A medida que aumentan las horas de operación acumuladas, las máquinas presentan un consumo energético más elevado debido al desgaste natural y la pérdida de eficiencia.

# %% [markdown]
# ---
#
# # 10. Visualización Avanzada y Multivariada (Seaborn)
#
# **Seaborn** permite llevar el análisis un paso más allá al integrar paletas de colores basadas en categorías y cálculos estadísticos automáticos.
#
# En esta etapa se construirán:
# 1. **Mapa de Calor (Heatmap):** Para identificar qué variables están fuertemente correlacionadas.
# 2. **Diagramas de Caja (Boxplots):** Para evaluar cómo difieren los rangos de operación entre máquinas sanas y defectuosas.
# 3. **Gráfico de Pares (Pairplot):** Para tener una visión panorámica de todas las interacciones.

# %%
# 1. Mapa de Calor (Heatmap)
plt.figure(figsize=(8, 6))

# Creamos una copia eliminando la columna de texto 'Falla' para que Pandas no intente hacer matemáticas con palabras
datos_corr = datos.drop(columns=['Falla'])

# Creamos una nueva columna binaria (1 = Sí, 0 = No) para medir matemáticamente la falla
datos_corr['Falla_Binaria'] = datos['Falla'].apply(lambda x: 1 if x == 'Sí' else 0)

# Calcular matriz de correlación solo con valores numéricos
matriz_correlacion = datos_corr.corr()

sns.heatmap(matriz_correlacion, annot=True, cmap='RdYlBu_r', fmt=".2f", linewidths=0.5)
plt.title("Mapa de Calor: Correlación de Variables Industriales", fontsize=14, pad=15)
plt.show()

# 2. Boxplots para identificar rangos críticos de Falla (Código Actualizado)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

sns.boxplot(ax=axes[0], x='Falla', y='Temperatura del Motor', data=datos, hue='Falla', palette={'No': '#2ecc71', 'Sí': '#e74c3c'}, legend=False)
axes[0].set_title('Temperatura vs Estado de Falla', fontsize=12)

sns.boxplot(ax=axes[1], x='Falla', y='Vibración', data=datos, hue='Falla', palette={'No': '#2ecc71', 'Sí': '#e74c3c'}, legend=False)
axes[1].set_title('Vibración vs Estado de Falla', fontsize=12)

plt.tight_layout()
plt.show()

# 3. Pairplot (Panorámica general multivariada)
sns.pairplot(datos, hue='Falla', palette={'No': '#3498db', 'Sí': '#e74c3c'},
    corner=True)
plt.suptitle('Relaciones Multivariadas: Máquinas Sanas vs Defectuosas', y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# # 11. Preguntas de Análisis del Caso 5
#
# A continuación, se da respuesta puntual a las preguntas de análisis establecidas para el caso de mantenimiento predictivo:
#
# 1. **¿Qué indicadores anticipan una falla?**
#    Los indicadores primarios que anticipan una falla inminente en los motores son el incremento inusual en la **Temperatura del Motor** (por encima de los 85°C) y un aumento en los niveles de **Vibración** (por encima de los 5.5 mm/s). Un incremento repentino en el **Consumo Eléctrico** también funciona como indicador secundario de pérdida de eficiencia.
#
# 2. **¿Qué comportamiento tienen las máquinas defectuosas?**
#    Las máquinas defectuosas operan fuera de los rangos normales estables. Presentan un comportamiento caracterizado por sobrecalentamiento térmico, alta oscilación mecánica (vibración excesiva), un consumo de energía ineficiente (mayor a 140 kWh) y, por lo general, acumulan más de 3,500 horas de uso operativo, lo que refleja un desgaste crítico por tiempo de servicio.
#
# 3. **¿Qué beneficios tendría un sistema de mantenimiento predictivo basado en IA?**
#    * **Reducción de paradas no planificadas:** Permite intervenir la máquina únicamente cuando sus parámetros de vibración y temperatura indican una falla inminente, evitando detener la producción de forma imprevista.
#    * **Ahorro económico:** Reduce los costos de reparación catastrófica y optimiza el uso de repuestos en inventario.
#    * **Planificación eficiente:** Permite programar las revisiones técnicas en horarios de baja demanda operativa de la fábrica.

# %% [markdown]
# # 12. Análisis Exploratorio (Hallazgos y Variables Relevantes)
#
# Siguiendo la estructura de entrega requerida, se detallan los hallazgos del análisis exploratorio de datos (EDA):
#
# ### **1. Hallazgos Encontrados**
# * Se detectó que las fallas del sistema no ocurren por variables aisladas, sino por un efecto acumulativo.
# * El desgaste de los componentes mecánicos se acelera notablemente cuando los equipos superan un umbral de uso de **3,500 horas**.
# * Existe un grupo de máquinas que operan de manera ineficiente, consumiendo más energía (kWh) de la estipulada en su ficha técnica, lo cual coincide casi en su totalidad con las máquinas etiquetadas con falla.
#
# ### **2. Relaciones entre Variables**
# * **Temperatura vs. Vibración:** Existe una fuerte relación positiva indirecta. El calor excesivo debilita la resistencia de los componentes, aumentando la vibración mecánica, y viceversa. Ambas variables crecen juntas en el grupo de máquinas defectuosas.
# * **Horas de Uso vs. Consumo Eléctrico:** Se observa que el consumo de energía aumenta proporcionalmente con las horas de operación, evidenciando pérdida de eficiencia energética debido al desgaste natural por fricción.
#
# ### **3. Variables más Relevantes**
# Para el desarrollo de un futuro modelo de Machine Learning, las variables predictoras más importantes y con mayor poder de discriminación son:
# 1. **Temperatura del Motor:** Es la variable con mayor correlación directa respecto al estado de falla de los equipos.
# 2. **Vibración:** Es indispensable para detectar fallas de origen puramente mecánico (desalineación, holguras o rodamientos dañados).
# 3. **Horas de Uso:** Funciona como la variable de control temporal de desgaste del activo físico.

# %% [markdown]
# ---
#
# # 13. Conclusiones
#
# 1. **La temperatura y la vibración son factores determinantes:** El análisis multivariado demostró que las fallas no son eventos aislados, sino la consecuencia de la combinación de alta fricción (temperatura) y desajustes mecánicos (vibración).
# 2. **El desgaste temporal es un factor de riesgo no lineal:** A través del análisis de dispersión, se concluye que las máquinas que superan las 3,500 horas de uso entran en una zona de riesgo exponencial, requiriendo revisiones más frecuentes.
# 3. **Pérdida de eficiencia energética:** Se identificó una relación directa entre el deterioro del equipo y el aumento del consumo eléctrico. Una máquina al borde de la falla consume en promedio un 20% más de energía, generando costos ocultos a la fábrica.
# 4. **Validación del uso de librerías en EDA:** Herramientas como NumPy y Seaborn resultan indispensables. NumPy permitió calcular umbrales y estadísticas con alta eficiencia computacional, mientras que el *Pairplot* de Seaborn fue clave para separar visualmente las clases (Máquina Sana vs. Defectuosa).
# 5. **Viabilidad para modelos predictivos:** La clara separación de los datos y las correlaciones marcadas indican que este dataset es altamente idóneo para entrenar algoritmos de clasificación supervisada (como Regresión Logística, Árboles de Decisión o Random Forest) con un alto nivel de precisión (Accuracy).

# %% [markdown]
# ---
#
# # 14. Recomendaciones Empresariales
#
# Como resultado del análisis técnico, se propone a la gerencia de la fábrica las siguientes acciones:
#
# 1. **Implementación de Sensores IoT (Internet de las Cosas):** Instalar sensores de temperatura y vibración de monitoreo continuo en los motores. Si una máquina supera los 80°C o un nivel de vibración de 4.5, el sistema debe emitir una alerta temprana.
# 2. **Reestructuración del Cronograma de Mantenimiento:** Ajustar los protocolos de revisión técnica para que ninguna máquina supere las 3,500 horas de uso continuo sin un mantenimiento preventivo profundo, independientemente de su estado aparente.
# 3. **Auditoría Energética Automatizada:** Monitorear el consumo en kWh. Cualquier máquina que presente picos sostenidos de energía superiores a 140 kWh debe ser retirada temporalmente de la línea de producción para revisión, ya que es un síntoma silencioso de falla inminente.

# %% [markdown]
# # 15. Reflexión de IA: Automatización de Toma de Decisiones en Mantenimiento Predictivo
#
# ### **Pregunta:** ¿Cómo podrían utilizarse técnicas de Machine Learning o Inteligencia Artificial para automatizar la toma de decisiones en este caso?
#
# Para automatizar la toma de decisiones en la planta de producción basada en el análisis de este caso de estudio, se propone la implementación de un **Sistema de Lazo Cerrado (Closed-Loop) apoyado en Machine Learning Supervisado y No Supervisado**.
#
# El proceso de automatización operaría bajo la siguiente arquitectura tecnológica:
#
# #### **1. Detección Temprana y Predicción de Fallas (Modelamiento de Machine Learning)**
# * **Modelos de Clasificación Supervisada:** Utilizando algoritmos como **XGBoost, Random Forest o Redes Neuronales Artificiales (ANN)**, entrenados con el histórico de datos recolectados (como el dataset sintético que analizamos). El modelo recibirá datos en tiempo real de los sensores y calculará constantemente la *Probabilidad de Falla ($P_{falla}$)* de cada máquina en una ventana de tiempo futura (por ejemplo, las próximas 48 horas de operación).
# * **Modelos de Detección de Anomalías (No Supervisado):** Implementando algoritmos como **Isolation Forests o Autoencoders (Deep Learning)** para detectar patrones inusuales en la vibración o temperatura que no hayan sido registrados previamente en el histórico, previniendo fallas inéditas.
#
# #### **2. Automatización de la Toma de Decisiones (Sin Intervención Humana Directa)**
# En lugar de depender de que un operario humano observe una pantalla y tome una decisión manual, la Inteligencia Artificial automatizará las acciones de la siguiente manera:
#
# * **Nivel 1: Alerta y Diagnóstico Automático (Notificación):** Si $P_{falla}$ supera el **60%**, la IA genera un diagnóstico predictivo automático (ej. *"Motor 4 presenta alta probabilidad de falla por sobrecalentamiento y desalineación mecánica"*) y envía una alerta instantánea vía bot de Telegram/Slack o correo al supervisor de turno.
# * **Nivel 2: Generación Autónoma de Órdenes de Trabajo (Integración ERP):** Si $P_{falla}$ supera el **75%**, el modelo de IA se integra mediante APIs con el software de gestión de activos de la empresa (como SAP PM o Máximo). El sistema generará automáticamente una **Orden de Trabajo Preventiva**, reservará los repuestos necesarios en el inventario de la fábrica y asignará la tarea al técnico calificado disponible según su agenda.
# * **Nivel 3: Control Adaptativo de Seguridad (Parada de Emergencia / Mitigación):** Si $P_{falla}$ supera el **90%** y los sensores detectan que la temperatura sobrepasa el umbral crítico de manera sostenida, la IA enviará una instrucción directa al **PLC (Controlador Lógico Programable)** de la máquina mediante protocolos industriales (como Modbus o OPC UA) para:
#   1. Reducir la velocidad/carga de la máquina de forma automática para disminuir la fricción y enfriar el motor.
#   2. Si el riesgo persiste, ejecutar una parada segura controlada para evitar daños catastróficos o accidentes laborales en la planta, todo esto en fracciones de segundo.
